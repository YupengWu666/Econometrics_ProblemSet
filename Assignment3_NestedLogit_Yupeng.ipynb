# %% [markdown]
# # Assignment 3 - Nested Logit Model
# Yupeng Wu

# %% [markdown]
# Compared with the MNL model, the nested logit model is more flexible and can capture the correlation between alternatives. In interms of log-likelihood, we have the following results:
# - MNL-nonlinear: -5223.841 (in class)
# - Nested Logit-nonlinear: -5046.323

# %%
import os
import json
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import random

# %%
from utils_ import format_data_neural_network_general

X,Y = format_data_neural_network_general()

random.seed(1234)
np.random.seed(1234)
split = list(zip(*[train_test_split(d,test_size = 0.25, random_state = 1234) for d in X]))
Xtrain, Xtest = split[0], split[1]
Ytrain, Ytest = train_test_split(Y,test_size = 0.25, random_state = 1234)
# Out:
# RAW DATA | The number of observations is 10,728.
# RAW DATA | The number of columns per observations is 29.
# DROPPING NO CHOICE | The number of observations is 10,719.
# 83 customer features.
# 12 product features.

# %%
# constructs the Nested MNL model class and a custom callback class

class NestedLogit(tf.keras.Model):
    
    def __init__(self):
        
        super(NestedLogit, self).__init__()
        self.intermediate = [Dense(10, activation="relu") for i in range(2)]
        self.last = Dense(1, activation="linear",
                          use_bias= False) 
        self.nl_name = "NestedLogit_nonlinear"
        
    def call(self,inputs):
        U = inputs[:3]
        Z = inputs[4:]
        Z = tf.keras.layers.Concatenate()(Z)

        U = [tf.keras.layers.Concatenate()([U[i],Z])  for i in range(3)]
        for j in range(2):
          U = [self.intermediate[j](U[i]) for i in range(3)]                
        U = [self.last(U[i]) for i in range(3)] 
        avail = inputs[3]

        combined = tf.keras.layers.Concatenate()(U)
        combined = tf.keras.layers.Activation(activation=tf.nn.softmax)(combined)
        combined = combined*avail

        nest1 = combined[:, :2]
        nest1_max = tf.expand_dims(tf.reduce_max(nest1, axis=1), axis=1)

        combined_level1 = tf.concat([nest1_max, tf.expand_dims(combined[:, 2], axis=1)], axis=1)
        combined_level1 = tf.math.divide(combined_level1,tf.reduce_sum(combined_level1, axis=1, keepdims=True))

        prob_nest1 = tf.math.divide(nest1,tf.reduce_sum(nest1, axis=1, keepdims=True)) * tf.expand_dims(combined_level1[:, 0], axis=1)
        prob = tf.concat([prob_nest1, tf.expand_dims(combined_level1[:, 1], axis=1)], axis=1)
        return prob
    
# constructs the Nested MNL model class and a custom callback class

class NestedLogit_linear(tf.keras.Model):
    
    def __init__(self):
        
        super(NestedLogit_linear, self).__init__()
        self.last = Dense(1, activation="linear",
                          use_bias= False) 
        self.nl_name = 'NestedLogit_linear'
        
    def call(self,inputs):
        U = inputs[:3]
        Z = inputs[4:]
        Z = tf.keras.layers.Concatenate()(Z)

        U = [tf.keras.layers.Concatenate()([U[i],Z])  for i in range(3)]            
        U = [self.last(U[i]) for i in range(3)] 
        avail = inputs[3]

        combined = tf.keras.layers.Concatenate()(U)
        combined = tf.keras.layers.Activation(activation=tf.nn.softmax)(combined)
        combined = combined*avail

        nest1 = combined[:, :2]
        nest1_max = tf.expand_dims(tf.reduce_max(nest1, axis=1), axis=1)

        combined_level1 = tf.concat([nest1_max, tf.expand_dims(combined[:, 2], axis=1)], axis=1)
        prob_level1 = tf.math.divide(combined_level1,tf.reduce_sum(combined_level1, axis=1, keepdims=True))

        prob_nest1 = tf.math.divide(nest1,tf.reduce_sum(nest1, axis=1, keepdims=True)) * tf.expand_dims(prob_level1[:, 0], axis=1)
        prob = tf.concat([prob_nest1, tf.expand_dims(prob_level1[:, 1], axis=1)], axis=1)

        return prob

# %%
##### Create model
model_nl = NestedLogit()
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.001)  #  #tf.keras.optimizers.Adam(learning_rate=0.001) # # # #
model_nl.compile(optimizer=optimizer, 
                    loss=loss, 
                    metrics = ["accuracy"])

es = EarlyStopping(monitor = 'val_loss',
                        patience = 20,
                        verbose = 0,
                        restore_best_weights =True)

callbacks = []
callbacks += [es]                
    
###### Fitting model
history = model_nl.fit(X,Y,
                    validation_split = 0.1,
                    batch_size= 32,
                    epochs= 200,
                    callbacks = callbacks,
                    verbose= 2, #0
                    shuffle=True)

y = model_nl.predict(X)
print('{} - Log-likelihood'.format(model_nl.nl_name), np.sum(np.array([np.log(y[i][Y[i]]) for i in range(len(Y))])))
# Out:
# Epoch 1/200
# 302/302 - 2s - loss: 0.8534 - accuracy: 0.5812 - val_loss: 0.7629 - val_accuracy: 0.6642 - 2s/epoch - 5ms/step
# Epoch 2/200
# 302/302 - 1s - loss: 0.7236 - accuracy: 0.6745 - val_loss: 0.7064 - val_accuracy: 0.6884 - 619ms/epoch - 2ms/step
# Epoch 3/200
# 302/302 - 0s - loss: 0.6819 - accuracy: 0.6901 - val_loss: 0.6715 - val_accuracy: 0.7034 - 467ms/epoch - 2ms/step
# Epoch 4/200
# 302/302 - 1s - loss: 0.6577 - accuracy: 0.7012 - val_loss: 0.6517 - val_accuracy: 0.7248 - 749ms/epoch - 2ms/step
# Epoch 5/200
# 302/302 - 1s - loss: 0.6407 - accuracy: 0.7121 - val_loss: 0.6365 - val_accuracy: 0.7276 - 508ms/epoch - 2ms/step
# Epoch 6/200
# 302/302 - 1s - loss: 0.6277 - accuracy: 0.7175 - val_loss: 0.6321 - val_accuracy: 0.7220 - 771ms/epoch - 3ms/step
# Epoch 7/200
# 302/302 - 1s - loss: 0.6176 - accuracy: 0.7299 - val_loss: 0.6239 - val_accuracy: 0.7155 - 616ms/epoch - 2ms/step
# Epoch 8/200
# 302/302 - 1s - loss: 0.6087 - accuracy: 0.7329 - val_loss: 0.6245 - val_accuracy: 0.7192 - 528ms/epoch - 2ms/step
# Epoch 9/200
# 302/302 - 0s - loss: 0.6014 - accuracy: 0.7376 - val_loss: 0.6133 - val_accuracy: 0.7276 - 498ms/epoch - 2ms/step
# Epoch 10/200
# 302/302 - 0s - loss: 0.5947 - accuracy: 0.7391 - val_loss: 0.6058 - val_accuracy: 0.7285 - 479ms/epoch - 2ms/step
# Epoch 11/200
# 302/302 - 0s - loss: 0.5890 - accuracy: 0.7437 - val_loss: 0.6127 - val_accuracy: 0.7155 - 478ms/epoch - 2ms/step
# Epoch 12/200
# 302/302 - 1s - loss: 0.5843 - accuracy: 0.7439 - val_loss: 0.6053 - val_accuracy: 0.7164 - 710ms/epoch - 2ms/step
# Epoch 13/200
# 302/302 - 1s - loss: 0.5782 - accuracy: 0.7468 - val_loss: 0.6082 - val_accuracy: 0.7295 - 540ms/epoch - 2ms/step
# Epoch 14/200
# 302/302 - 1s - loss: 0.5757 - accuracy: 0.7482 - val_loss: 0.6028 - val_accuracy: 0.7211 - 702ms/epoch - 2ms/step
# Epoch 15/200
# 302/302 - 1s - loss: 0.5710 - accuracy: 0.7487 - val_loss: 0.6043 - val_accuracy: 0.7211 - 510ms/epoch - 2ms/step
# Epoch 16/200
# 302/302 - 1s - loss: 0.5682 - accuracy: 0.7513 - val_loss: 0.5953 - val_accuracy: 0.7304 - 509ms/epoch - 2ms/step
# Epoch 17/200
# 302/302 - 0s - loss: 0.5652 - accuracy: 0.7513 - val_loss: 0.5925 - val_accuracy: 0.7257 - 455ms/epoch - 2ms/step
# Epoch 18/200
# 302/302 - 0s - loss: 0.5633 - accuracy: 0.7543 - val_loss: 0.5875 - val_accuracy: 0.7369 - 478ms/epoch - 2ms/step
# Epoch 19/200
# 302/302 - 1s - loss: 0.5593 - accuracy: 0.7551 - val_loss: 0.5922 - val_accuracy: 0.7313 - 510ms/epoch - 2ms/step
# Epoch 20/200
# 302/302 - 1s - loss: 0.5564 - accuracy: 0.7588 - val_loss: 0.5916 - val_accuracy: 0.7285 - 505ms/epoch - 2ms/step
# Epoch 21/200
# 302/302 - 1s - loss: 0.5540 - accuracy: 0.7585 - val_loss: 0.5898 - val_accuracy: 0.7332 - 524ms/epoch - 2ms/step
# Epoch 22/200
# 302/302 - 1s - loss: 0.5526 - accuracy: 0.7589 - val_loss: 0.5852 - val_accuracy: 0.7360 - 689ms/epoch - 2ms/step
# Epoch 23/200
# 302/302 - 1s - loss: 0.5496 - accuracy: 0.7621 - val_loss: 0.5861 - val_accuracy: 0.7304 - 606ms/epoch - 2ms/step
# Epoch 24/200
# 302/302 - 1s - loss: 0.5479 - accuracy: 0.7605 - val_loss: 0.5804 - val_accuracy: 0.7416 - 521ms/epoch - 2ms/step
# Epoch 25/200
# 302/302 - 1s - loss: 0.5470 - accuracy: 0.7633 - val_loss: 0.5782 - val_accuracy: 0.7369 - 511ms/epoch - 2ms/step
# Epoch 26/200
# 302/302 - 1s - loss: 0.5451 - accuracy: 0.7612 - val_loss: 0.5765 - val_accuracy: 0.7341 - 542ms/epoch - 2ms/step
# Epoch 27/200
# 302/302 - 0s - loss: 0.5436 - accuracy: 0.7617 - val_loss: 0.5755 - val_accuracy: 0.7341 - 473ms/epoch - 2ms/step
# Epoch 28/200
# 302/302 - 1s - loss: 0.5415 - accuracy: 0.7642 - val_loss: 0.5758 - val_accuracy: 0.7425 - 523ms/epoch - 2ms/step
# Epoch 29/200
# 302/302 - 0s - loss: 0.5404 - accuracy: 0.7627 - val_loss: 0.5768 - val_accuracy: 0.7388 - 479ms/epoch - 2ms/step
# Epoch 30/200
# 302/302 - 0s - loss: 0.5396 - accuracy: 0.7659 - val_loss: 0.5721 - val_accuracy: 0.7416 - 489ms/epoch - 2ms/step
# Epoch 31/200
# 302/302 - 0s - loss: 0.5397 - accuracy: 0.7655 - val_loss: 0.5682 - val_accuracy: 0.7472 - 463ms/epoch - 2ms/step
# Epoch 32/200
# 302/302 - 1s - loss: 0.5362 - accuracy: 0.7696 - val_loss: 0.5674 - val_accuracy: 0.7472 - 574ms/epoch - 2ms/step
# Epoch 33/200
# 302/302 - 1s - loss: 0.5358 - accuracy: 0.7705 - val_loss: 0.5666 - val_accuracy: 0.7528 - 551ms/epoch - 2ms/step
# Epoch 34/200
# 302/302 - 1s - loss: 0.5338 - accuracy: 0.7708 - val_loss: 0.5681 - val_accuracy: 0.7509 - 526ms/epoch - 2ms/step
# Epoch 35/200
# 302/302 - 1s - loss: 0.5326 - accuracy: 0.7717 - val_loss: 0.5692 - val_accuracy: 0.7519 - 513ms/epoch - 2ms/step
# Epoch 36/200
# 302/302 - 1s - loss: 0.5325 - accuracy: 0.7699 - val_loss: 0.5710 - val_accuracy: 0.7491 - 505ms/epoch - 2ms/step
# Epoch 37/200
# 302/302 - 0s - loss: 0.5313 - accuracy: 0.7704 - val_loss: 0.5655 - val_accuracy: 0.7509 - 475ms/epoch - 2ms/step
# Epoch 38/200
# 302/302 - 0s - loss: 0.5301 - accuracy: 0.7716 - val_loss: 0.5645 - val_accuracy: 0.7481 - 490ms/epoch - 2ms/step
# Epoch 39/200
# 302/302 - 0s - loss: 0.5274 - accuracy: 0.7737 - val_loss: 0.5662 - val_accuracy: 0.7509 - 495ms/epoch - 2ms/step
# Epoch 40/200
# 302/302 - 1s - loss: 0.5263 - accuracy: 0.7713 - val_loss: 0.5609 - val_accuracy: 0.7519 - 587ms/epoch - 2ms/step
# Epoch 41/200
# 302/302 - 1s - loss: 0.5252 - accuracy: 0.7731 - val_loss: 0.5625 - val_accuracy: 0.7481 - 515ms/epoch - 2ms/step
# Epoch 42/200
# 302/302 - 1s - loss: 0.5242 - accuracy: 0.7755 - val_loss: 0.5597 - val_accuracy: 0.7519 - 544ms/epoch - 2ms/step
# Epoch 43/200
# 302/302 - 1s - loss: 0.5230 - accuracy: 0.7752 - val_loss: 0.5636 - val_accuracy: 0.7500 - 551ms/epoch - 2ms/step
# Epoch 44/200
# 302/302 - 0s - loss: 0.5219 - accuracy: 0.7752 - val_loss: 0.5601 - val_accuracy: 0.7491 - 494ms/epoch - 2ms/step
# Epoch 45/200
# 302/302 - 1s - loss: 0.5208 - accuracy: 0.7781 - val_loss: 0.5593 - val_accuracy: 0.7519 - 701ms/epoch - 2ms/step
# Epoch 46/200
# 302/302 - 1s - loss: 0.5191 - accuracy: 0.7736 - val_loss: 0.5608 - val_accuracy: 0.7565 - 676ms/epoch - 2ms/step
# Epoch 47/200
# 302/302 - 1s - loss: 0.5183 - accuracy: 0.7774 - val_loss: 0.5586 - val_accuracy: 0.7491 - 567ms/epoch - 2ms/step
# Epoch 48/200
# 302/302 - 1s - loss: 0.5154 - accuracy: 0.7758 - val_loss: 0.5625 - val_accuracy: 0.7444 - 508ms/epoch - 2ms/step
# Epoch 49/200
# 302/302 - 0s - loss: 0.5159 - accuracy: 0.7759 - val_loss: 0.5622 - val_accuracy: 0.7519 - 490ms/epoch - 2ms/step
# Epoch 50/200
# 302/302 - 1s - loss: 0.5136 - accuracy: 0.7814 - val_loss: 0.5613 - val_accuracy: 0.7575 - 521ms/epoch - 2ms/step
# Epoch 51/200
# 302/302 - 1s - loss: 0.5134 - accuracy: 0.7785 - val_loss: 0.5595 - val_accuracy: 0.7593 - 505ms/epoch - 2ms/step
# Epoch 52/200
# 302/302 - 0s - loss: 0.5128 - accuracy: 0.7811 - val_loss: 0.5586 - val_accuracy: 0.7593 - 491ms/epoch - 2ms/step
# Epoch 53/200
# 302/302 - 1s - loss: 0.5125 - accuracy: 0.7788 - val_loss: 0.5596 - val_accuracy: 0.7547 - 566ms/epoch - 2ms/step
# Epoch 54/200
# 302/302 - 1s - loss: 0.5104 - accuracy: 0.7797 - val_loss: 0.5602 - val_accuracy: 0.7491 - 504ms/epoch - 2ms/step
# Epoch 55/200
# 302/302 - 0s - loss: 0.5091 - accuracy: 0.7818 - val_loss: 0.5604 - val_accuracy: 0.7453 - 468ms/epoch - 2ms/step
# Epoch 56/200
# 302/302 - 0s - loss: 0.5089 - accuracy: 0.7796 - val_loss: 0.5648 - val_accuracy: 0.7453 - 479ms/epoch - 2ms/step
# Epoch 57/200
# 302/302 - 1s - loss: 0.5089 - accuracy: 0.7806 - val_loss: 0.5616 - val_accuracy: 0.7444 - 504ms/epoch - 2ms/step
# Epoch 58/200
# 302/302 - 1s - loss: 0.5074 - accuracy: 0.7839 - val_loss: 0.5567 - val_accuracy: 0.7528 - 506ms/epoch - 2ms/step
# Epoch 59/200
# 302/302 - 1s - loss: 0.5068 - accuracy: 0.7806 - val_loss: 0.5628 - val_accuracy: 0.7519 - 634ms/epoch - 2ms/step
# Epoch 60/200
# 302/302 - 1s - loss: 0.5052 - accuracy: 0.7811 - val_loss: 0.5579 - val_accuracy: 0.7453 - 841ms/epoch - 3ms/step
# Epoch 61/200
# 302/302 - 1s - loss: 0.5051 - accuracy: 0.7843 - val_loss: 0.5591 - val_accuracy: 0.7677 - 851ms/epoch - 3ms/step
# Epoch 62/200
# 302/302 - 1s - loss: 0.5027 - accuracy: 0.7810 - val_loss: 0.5589 - val_accuracy: 0.7621 - 776ms/epoch - 3ms/step
# Epoch 63/200
# 302/302 - 1s - loss: 0.5036 - accuracy: 0.7814 - val_loss: 0.5609 - val_accuracy: 0.7453 - 556ms/epoch - 2ms/step
# Epoch 64/200
# 302/302 - 1s - loss: 0.5024 - accuracy: 0.7823 - val_loss: 0.5680 - val_accuracy: 0.7491 - 504ms/epoch - 2ms/step
# Epoch 65/200
# 302/302 - 1s - loss: 0.5024 - accuracy: 0.7847 - val_loss: 0.5548 - val_accuracy: 0.7640 - 831ms/epoch - 3ms/step
# Epoch 66/200
# 302/302 - 1s - loss: 0.5008 - accuracy: 0.7826 - val_loss: 0.5562 - val_accuracy: 0.7603 - 567ms/epoch - 2ms/step
# Epoch 67/200
# 302/302 - 1s - loss: 0.5004 - accuracy: 0.7842 - val_loss: 0.5538 - val_accuracy: 0.7547 - 551ms/epoch - 2ms/step
# Epoch 68/200
# 302/302 - 0s - loss: 0.4994 - accuracy: 0.7865 - val_loss: 0.5512 - val_accuracy: 0.7528 - 476ms/epoch - 2ms/step
# Epoch 69/200
# 302/302 - 0s - loss: 0.4998 - accuracy: 0.7863 - val_loss: 0.5582 - val_accuracy: 0.7556 - 462ms/epoch - 2ms/step
# Epoch 70/200
# 302/302 - 0s - loss: 0.4981 - accuracy: 0.7823 - val_loss: 0.5558 - val_accuracy: 0.7603 - 461ms/epoch - 2ms/step
# Epoch 71/200
# 302/302 - 1s - loss: 0.4982 - accuracy: 0.7869 - val_loss: 0.5530 - val_accuracy: 0.7603 - 508ms/epoch - 2ms/step
# Epoch 72/200
# 302/302 - 0s - loss: 0.4971 - accuracy: 0.7866 - val_loss: 0.5605 - val_accuracy: 0.7537 - 476ms/epoch - 2ms/step
# Epoch 73/200
# 302/302 - 0s - loss: 0.4973 - accuracy: 0.7837 - val_loss: 0.5624 - val_accuracy: 0.7537 - 473ms/epoch - 2ms/step
# Epoch 74/200
# 302/302 - 0s - loss: 0.4964 - accuracy: 0.7867 - val_loss: 0.5500 - val_accuracy: 0.7584 - 491ms/epoch - 2ms/step
# Epoch 75/200
# 302/302 - 0s - loss: 0.4968 - accuracy: 0.7871 - val_loss: 0.5545 - val_accuracy: 0.7659 - 447ms/epoch - 1ms/step
# Epoch 76/200
# 302/302 - 1s - loss: 0.4966 - accuracy: 0.7863 - val_loss: 0.5545 - val_accuracy: 0.7659 - 506ms/epoch - 2ms/step
# Epoch 77/200
# 302/302 - 0s - loss: 0.4954 - accuracy: 0.7848 - val_loss: 0.5517 - val_accuracy: 0.7547 - 457ms/epoch - 2ms/step
# Epoch 78/200
# 302/302 - 0s - loss: 0.4964 - accuracy: 0.7872 - val_loss: 0.5532 - val_accuracy: 0.7649 - 490ms/epoch - 2ms/step
# Epoch 79/200
# 302/302 - 0s - loss: 0.4941 - accuracy: 0.7870 - val_loss: 0.5488 - val_accuracy: 0.7537 - 459ms/epoch - 2ms/step
# Epoch 80/200
# 302/302 - 0s - loss: 0.4949 - accuracy: 0.7860 - val_loss: 0.5585 - val_accuracy: 0.7584 - 460ms/epoch - 2ms/step
# Epoch 81/200
# 302/302 - 0s - loss: 0.4927 - accuracy: 0.7866 - val_loss: 0.5488 - val_accuracy: 0.7677 - 459ms/epoch - 2ms/step
# Epoch 82/200
# 302/302 - 0s - loss: 0.4936 - accuracy: 0.7866 - val_loss: 0.5525 - val_accuracy: 0.7593 - 459ms/epoch - 2ms/step
# Epoch 83/200
# 302/302 - 0s - loss: 0.4926 - accuracy: 0.7874 - val_loss: 0.5531 - val_accuracy: 0.7621 - 489ms/epoch - 2ms/step
# Epoch 84/200
# 302/302 - 0s - loss: 0.4920 - accuracy: 0.7892 - val_loss: 0.5579 - val_accuracy: 0.7547 - 488ms/epoch - 2ms/step
# Epoch 85/200
# 302/302 - 0s - loss: 0.4930 - accuracy: 0.7883 - val_loss: 0.5527 - val_accuracy: 0.7547 - 458ms/epoch - 2ms/step
# Epoch 86/200
# 302/302 - 1s - loss: 0.4914 - accuracy: 0.7893 - val_loss: 0.5513 - val_accuracy: 0.7631 - 506ms/epoch - 2ms/step
# Epoch 87/200
# 302/302 - 1s - loss: 0.4923 - accuracy: 0.7864 - val_loss: 0.5449 - val_accuracy: 0.7612 - 512ms/epoch - 2ms/step
# Epoch 88/200
# 302/302 - 1s - loss: 0.4913 - accuracy: 0.7876 - val_loss: 0.5462 - val_accuracy: 0.7649 - 556ms/epoch - 2ms/step
# Epoch 89/200
# 302/302 - 1s - loss: 0.4909 - accuracy: 0.7882 - val_loss: 0.5596 - val_accuracy: 0.7547 - 508ms/epoch - 2ms/step
# Epoch 90/200
# 302/302 - 1s - loss: 0.4926 - accuracy: 0.7865 - val_loss: 0.5512 - val_accuracy: 0.7621 - 1s/epoch - 4ms/step
# Epoch 91/200
# 302/302 - 1s - loss: 0.4903 - accuracy: 0.7884 - val_loss: 0.5526 - val_accuracy: 0.7659 - 1s/epoch - 4ms/step
# Epoch 92/200
# 302/302 - 1s - loss: 0.4899 - accuracy: 0.7879 - val_loss: 0.5500 - val_accuracy: 0.7603 - 778ms/epoch - 3ms/step
# Epoch 93/200
# 302/302 - 1s - loss: 0.4902 - accuracy: 0.7892 - val_loss: 0.5473 - val_accuracy: 0.7584 - 950ms/epoch - 3ms/step
# Epoch 94/200
# 302/302 - 1s - loss: 0.4895 - accuracy: 0.7895 - val_loss: 0.5466 - val_accuracy: 0.7631 - 914ms/epoch - 3ms/step
# Epoch 95/200
# 302/302 - 1s - loss: 0.4889 - accuracy: 0.7924 - val_loss: 0.5466 - val_accuracy: 0.7668 - 1s/epoch - 4ms/step
# Epoch 96/200
# 302/302 - 1s - loss: 0.4897 - accuracy: 0.7900 - val_loss: 0.5498 - val_accuracy: 0.7593 - 793ms/epoch - 3ms/step
# Epoch 97/200
# 302/302 - 0s - loss: 0.4892 - accuracy: 0.7924 - val_loss: 0.5471 - val_accuracy: 0.7715 - 471ms/epoch - 2ms/step
# Epoch 98/200
# 302/302 - 1s - loss: 0.4881 - accuracy: 0.7889 - val_loss: 0.5568 - val_accuracy: 0.7565 - 527ms/epoch - 2ms/step
# Epoch 99/200
# 302/302 - 1s - loss: 0.4875 - accuracy: 0.7924 - val_loss: 0.5461 - val_accuracy: 0.7687 - 543ms/epoch - 2ms/step
# Epoch 100/200
# 302/302 - 1s - loss: 0.4876 - accuracy: 0.7894 - val_loss: 0.5466 - val_accuracy: 0.7659 - 548ms/epoch - 2ms/step
# Epoch 101/200
# 302/302 - 1s - loss: 0.4872 - accuracy: 0.7920 - val_loss: 0.5409 - val_accuracy: 0.7687 - 568ms/epoch - 2ms/step
# Epoch 102/200
# 302/302 - 1s - loss: 0.4886 - accuracy: 0.7925 - val_loss: 0.5485 - val_accuracy: 0.7537 - 594ms/epoch - 2ms/step
# Epoch 103/200
# 302/302 - 1s - loss: 0.4868 - accuracy: 0.7899 - val_loss: 0.5462 - val_accuracy: 0.7612 - 567ms/epoch - 2ms/step
# Epoch 104/200
# 302/302 - 1s - loss: 0.4882 - accuracy: 0.7921 - val_loss: 0.5419 - val_accuracy: 0.7649 - 573ms/epoch - 2ms/step
# Epoch 105/200
# 302/302 - 1s - loss: 0.4869 - accuracy: 0.7883 - val_loss: 0.5431 - val_accuracy: 0.7687 - 604ms/epoch - 2ms/step
# Epoch 106/200
# 302/302 - 1s - loss: 0.4866 - accuracy: 0.7911 - val_loss: 0.5455 - val_accuracy: 0.7631 - 548ms/epoch - 2ms/step
# Epoch 107/200
# 302/302 - 1s - loss: 0.4850 - accuracy: 0.7901 - val_loss: 0.5450 - val_accuracy: 0.7668 - 596ms/epoch - 2ms/step
# Epoch 108/200
# 302/302 - 1s - loss: 0.4866 - accuracy: 0.7936 - val_loss: 0.5494 - val_accuracy: 0.7640 - 699ms/epoch - 2ms/step
# Epoch 109/200
# 302/302 - 1s - loss: 0.4864 - accuracy: 0.7904 - val_loss: 0.5471 - val_accuracy: 0.7640 - 502ms/epoch - 2ms/step
# Epoch 110/200
# 302/302 - 1s - loss: 0.4867 - accuracy: 0.7916 - val_loss: 0.5432 - val_accuracy: 0.7603 - 590ms/epoch - 2ms/step
# Epoch 111/200
# 302/302 - 1s - loss: 0.4858 - accuracy: 0.7913 - val_loss: 0.5466 - val_accuracy: 0.7603 - 677ms/epoch - 2ms/step
# Epoch 112/200
# 302/302 - 1s - loss: 0.4861 - accuracy: 0.7907 - val_loss: 0.5437 - val_accuracy: 0.7621 - 662ms/epoch - 2ms/step
# Epoch 113/200
# 302/302 - 1s - loss: 0.4861 - accuracy: 0.7930 - val_loss: 0.5420 - val_accuracy: 0.7724 - 604ms/epoch - 2ms/step
# Epoch 114/200
# 302/302 - 1s - loss: 0.4860 - accuracy: 0.7916 - val_loss: 0.5400 - val_accuracy: 0.7677 - 535ms/epoch - 2ms/step
# Epoch 115/200
# 302/302 - 1s - loss: 0.4854 - accuracy: 0.7914 - val_loss: 0.5458 - val_accuracy: 0.7696 - 569ms/epoch - 2ms/step
# Epoch 116/200
# 302/302 - 1s - loss: 0.4852 - accuracy: 0.7962 - val_loss: 0.5416 - val_accuracy: 0.7677 - 528ms/epoch - 2ms/step
# Epoch 117/200
# 302/302 - 0s - loss: 0.4858 - accuracy: 0.7892 - val_loss: 0.5486 - val_accuracy: 0.7696 - 483ms/epoch - 2ms/step
# Epoch 118/200
# 302/302 - 1s - loss: 0.4849 - accuracy: 0.7945 - val_loss: 0.5482 - val_accuracy: 0.7687 - 549ms/epoch - 2ms/step
# Epoch 119/200
# 302/302 - 0s - loss: 0.4847 - accuracy: 0.7927 - val_loss: 0.5472 - val_accuracy: 0.7687 - 487ms/epoch - 2ms/step
# Epoch 120/200
# 302/302 - 0s - loss: 0.4845 - accuracy: 0.7912 - val_loss: 0.5392 - val_accuracy: 0.7649 - 471ms/epoch - 2ms/step
# Epoch 121/200
# 302/302 - 0s - loss: 0.4856 - accuracy: 0.7893 - val_loss: 0.5410 - val_accuracy: 0.7631 - 459ms/epoch - 2ms/step
# Epoch 122/200
# 302/302 - 0s - loss: 0.4841 - accuracy: 0.7931 - val_loss: 0.5462 - val_accuracy: 0.7743 - 460ms/epoch - 2ms/step
# Epoch 123/200
# 302/302 - 0s - loss: 0.4840 - accuracy: 0.7941 - val_loss: 0.5453 - val_accuracy: 0.7640 - 460ms/epoch - 2ms/step
# Epoch 124/200
# 302/302 - 0s - loss: 0.4832 - accuracy: 0.7932 - val_loss: 0.5409 - val_accuracy: 0.7705 - 462ms/epoch - 2ms/step
# Epoch 125/200
# 302/302 - 0s - loss: 0.4846 - accuracy: 0.7908 - val_loss: 0.5388 - val_accuracy: 0.7743 - 464ms/epoch - 2ms/step
# Epoch 126/200
# 302/302 - 0s - loss: 0.4832 - accuracy: 0.7907 - val_loss: 0.5428 - val_accuracy: 0.7687 - 498ms/epoch - 2ms/step
# Epoch 127/200
# 302/302 - 1s - loss: 0.4839 - accuracy: 0.7939 - val_loss: 0.5388 - val_accuracy: 0.7696 - 508ms/epoch - 2ms/step
# Epoch 128/200
# 302/302 - 0s - loss: 0.4832 - accuracy: 0.7921 - val_loss: 0.5448 - val_accuracy: 0.7659 - 494ms/epoch - 2ms/step
# Epoch 129/200
# 302/302 - 0s - loss: 0.4842 - accuracy: 0.7914 - val_loss: 0.5383 - val_accuracy: 0.7715 - 479ms/epoch - 2ms/step
# Epoch 130/200
# 302/302 - 1s - loss: 0.4829 - accuracy: 0.7908 - val_loss: 0.5419 - val_accuracy: 0.7649 - 557ms/epoch - 2ms/step
# Epoch 131/200
# 302/302 - 0s - loss: 0.4827 - accuracy: 0.7929 - val_loss: 0.5479 - val_accuracy: 0.7612 - 446ms/epoch - 1ms/step
# Epoch 132/200
# 302/302 - 1s - loss: 0.4841 - accuracy: 0.7928 - val_loss: 0.5404 - val_accuracy: 0.7668 - 546ms/epoch - 2ms/step
# Epoch 133/200
# 302/302 - 1s - loss: 0.4821 - accuracy: 0.7909 - val_loss: 0.5407 - val_accuracy: 0.7696 - 575ms/epoch - 2ms/step
# Epoch 134/200
# 302/302 - 1s - loss: 0.4821 - accuracy: 0.7941 - val_loss: 0.5423 - val_accuracy: 0.7696 - 758ms/epoch - 3ms/step
# Epoch 135/200
# 302/302 - 1s - loss: 0.4818 - accuracy: 0.7945 - val_loss: 0.5416 - val_accuracy: 0.7715 - 624ms/epoch - 2ms/step
# Epoch 136/200
# 302/302 - 1s - loss: 0.4825 - accuracy: 0.7936 - val_loss: 0.5383 - val_accuracy: 0.7733 - 557ms/epoch - 2ms/step
# Epoch 137/200
# 302/302 - 1s - loss: 0.4815 - accuracy: 0.7919 - val_loss: 0.5372 - val_accuracy: 0.7659 - 531ms/epoch - 2ms/step
# Epoch 138/200
# 302/302 - 1s - loss: 0.4818 - accuracy: 0.7926 - val_loss: 0.5365 - val_accuracy: 0.7761 - 513ms/epoch - 2ms/step
# Epoch 139/200
# 302/302 - 0s - loss: 0.4808 - accuracy: 0.7941 - val_loss: 0.5368 - val_accuracy: 0.7752 - 462ms/epoch - 2ms/step
# Epoch 140/200
# 302/302 - 1s - loss: 0.4813 - accuracy: 0.7925 - val_loss: 0.5376 - val_accuracy: 0.7696 - 773ms/epoch - 3ms/step
# Epoch 141/200
# 302/302 - 1s - loss: 0.4808 - accuracy: 0.7941 - val_loss: 0.5411 - val_accuracy: 0.7780 - 1s/epoch - 4ms/step
# Epoch 142/200
# 302/302 - 1s - loss: 0.4805 - accuracy: 0.7915 - val_loss: 0.5387 - val_accuracy: 0.7743 - 586ms/epoch - 2ms/step
# Epoch 143/200
# 302/302 - 1s - loss: 0.4796 - accuracy: 0.7942 - val_loss: 0.5392 - val_accuracy: 0.7733 - 857ms/epoch - 3ms/step
# Epoch 144/200
# 302/302 - 1s - loss: 0.4805 - accuracy: 0.7932 - val_loss: 0.5398 - val_accuracy: 0.7696 - 742ms/epoch - 2ms/step
# Epoch 145/200
# 302/302 - 1s - loss: 0.4798 - accuracy: 0.7938 - val_loss: 0.5411 - val_accuracy: 0.7724 - 657ms/epoch - 2ms/step
# Epoch 146/200
# 302/302 - 1s - loss: 0.4808 - accuracy: 0.7963 - val_loss: 0.5384 - val_accuracy: 0.7733 - 544ms/epoch - 2ms/step
# Epoch 147/200
# 302/302 - 1s - loss: 0.4785 - accuracy: 0.7953 - val_loss: 0.5368 - val_accuracy: 0.7649 - 522ms/epoch - 2ms/step
# Epoch 148/200
# 302/302 - 1s - loss: 0.4786 - accuracy: 0.7963 - val_loss: 0.5389 - val_accuracy: 0.7687 - 562ms/epoch - 2ms/step
# Epoch 149/200
# 302/302 - 1s - loss: 0.4804 - accuracy: 0.7945 - val_loss: 0.5374 - val_accuracy: 0.7771 - 641ms/epoch - 2ms/step
# Epoch 150/200
# 302/302 - 1s - loss: 0.4795 - accuracy: 0.7942 - val_loss: 0.5353 - val_accuracy: 0.7715 - 602ms/epoch - 2ms/step
# Epoch 151/200
# 302/302 - 1s - loss: 0.4789 - accuracy: 0.7924 - val_loss: 0.5436 - val_accuracy: 0.7677 - 509ms/epoch - 2ms/step
# Epoch 152/200
# 302/302 - 0s - loss: 0.4792 - accuracy: 0.7939 - val_loss: 0.5418 - val_accuracy: 0.7696 - 495ms/epoch - 2ms/step
# Epoch 153/200
# 302/302 - 1s - loss: 0.4809 - accuracy: 0.7917 - val_loss: 0.5369 - val_accuracy: 0.7687 - 510ms/epoch - 2ms/step
# Epoch 154/200
# 302/302 - 1s - loss: 0.4787 - accuracy: 0.7938 - val_loss: 0.5338 - val_accuracy: 0.7799 - 586ms/epoch - 2ms/step
# Epoch 155/200
# 302/302 - 1s - loss: 0.4783 - accuracy: 0.7982 - val_loss: 0.5407 - val_accuracy: 0.7724 - 668ms/epoch - 2ms/step
# Epoch 156/200
# 302/302 - 1s - loss: 0.4791 - accuracy: 0.7937 - val_loss: 0.5393 - val_accuracy: 0.7696 - 571ms/epoch - 2ms/step
# Epoch 157/200
# 302/302 - 1s - loss: 0.4782 - accuracy: 0.7954 - val_loss: 0.5341 - val_accuracy: 0.7761 - 563ms/epoch - 2ms/step
# Epoch 158/200
# 302/302 - 1s - loss: 0.4790 - accuracy: 0.7959 - val_loss: 0.5458 - val_accuracy: 0.7649 - 596ms/epoch - 2ms/step
# Epoch 159/200
# 302/302 - 1s - loss: 0.4783 - accuracy: 0.7947 - val_loss: 0.5338 - val_accuracy: 0.7743 - 591ms/epoch - 2ms/step
# Epoch 160/200
# 302/302 - 1s - loss: 0.4783 - accuracy: 0.7942 - val_loss: 0.5369 - val_accuracy: 0.7789 - 565ms/epoch - 2ms/step
# Epoch 161/200
# 302/302 - 1s - loss: 0.4770 - accuracy: 0.7925 - val_loss: 0.5399 - val_accuracy: 0.7631 - 559ms/epoch - 2ms/step
# Epoch 162/200
# 302/302 - 1s - loss: 0.4770 - accuracy: 0.7940 - val_loss: 0.5364 - val_accuracy: 0.7733 - 550ms/epoch - 2ms/step
# Epoch 163/200
# 302/302 - 1s - loss: 0.4774 - accuracy: 0.7969 - val_loss: 0.5345 - val_accuracy: 0.7799 - 519ms/epoch - 2ms/step
# Epoch 164/200
# 302/302 - 0s - loss: 0.4776 - accuracy: 0.7947 - val_loss: 0.5364 - val_accuracy: 0.7761 - 489ms/epoch - 2ms/step
# Epoch 165/200
# 302/302 - 0s - loss: 0.4768 - accuracy: 0.7949 - val_loss: 0.5421 - val_accuracy: 0.7640 - 473ms/epoch - 2ms/step
# Epoch 166/200
# 302/302 - 0s - loss: 0.4779 - accuracy: 0.7932 - val_loss: 0.5359 - val_accuracy: 0.7705 - 456ms/epoch - 2ms/step
# Epoch 167/200
# 302/302 - 1s - loss: 0.4763 - accuracy: 0.7960 - val_loss: 0.5424 - val_accuracy: 0.7668 - 510ms/epoch - 2ms/step
# Epoch 168/200
# 302/302 - 0s - loss: 0.4764 - accuracy: 0.7955 - val_loss: 0.5318 - val_accuracy: 0.7780 - 493ms/epoch - 2ms/step
# Epoch 169/200
# 302/302 - 0s - loss: 0.4768 - accuracy: 0.7960 - val_loss: 0.5390 - val_accuracy: 0.7705 - 463ms/epoch - 2ms/step
# Epoch 170/200
# 302/302 - 0s - loss: 0.4766 - accuracy: 0.7948 - val_loss: 0.5389 - val_accuracy: 0.7677 - 460ms/epoch - 2ms/step
# Epoch 171/200
# 302/302 - 0s - loss: 0.4756 - accuracy: 0.7961 - val_loss: 0.5451 - val_accuracy: 0.7584 - 444ms/epoch - 1ms/step
# Epoch 172/200
# 302/302 - 0s - loss: 0.4767 - accuracy: 0.7943 - val_loss: 0.5366 - val_accuracy: 0.7752 - 479ms/epoch - 2ms/step
# Epoch 173/200
# 302/302 - 0s - loss: 0.4766 - accuracy: 0.7955 - val_loss: 0.5353 - val_accuracy: 0.7724 - 456ms/epoch - 2ms/step
# Epoch 174/200
# 302/302 - 0s - loss: 0.4757 - accuracy: 0.7944 - val_loss: 0.5351 - val_accuracy: 0.7752 - 498ms/epoch - 2ms/step
# Epoch 175/200
# 302/302 - 0s - loss: 0.4758 - accuracy: 0.7968 - val_loss: 0.5395 - val_accuracy: 0.7743 - 459ms/epoch - 2ms/step
# Epoch 176/200
# 302/302 - 0s - loss: 0.4762 - accuracy: 0.7957 - val_loss: 0.5392 - val_accuracy: 0.7677 - 473ms/epoch - 2ms/step
# Epoch 177/200
# 302/302 - 0s - loss: 0.4766 - accuracy: 0.7947 - val_loss: 0.5346 - val_accuracy: 0.7808 - 458ms/epoch - 2ms/step
# Epoch 178/200
# 302/302 - 0s - loss: 0.4753 - accuracy: 0.7966 - val_loss: 0.5400 - val_accuracy: 0.7724 - 476ms/epoch - 2ms/step
# Epoch 179/200
# 302/302 - 0s - loss: 0.4760 - accuracy: 0.7979 - val_loss: 0.5324 - val_accuracy: 0.7752 - 474ms/epoch - 2ms/step
# Epoch 180/200
# 302/302 - 0s - loss: 0.4753 - accuracy: 0.7977 - val_loss: 0.5329 - val_accuracy: 0.7771 - 458ms/epoch - 2ms/step
# Epoch 181/200
# 302/302 - 1s - loss: 0.4754 - accuracy: 0.7937 - val_loss: 0.5325 - val_accuracy: 0.7752 - 524ms/epoch - 2ms/step
# Epoch 182/200
# 302/302 - 0s - loss: 0.4737 - accuracy: 0.8001 - val_loss: 0.5443 - val_accuracy: 0.7640 - 489ms/epoch - 2ms/step
# Epoch 183/200
# 302/302 - 1s - loss: 0.4762 - accuracy: 0.7962 - val_loss: 0.5316 - val_accuracy: 0.7715 - 506ms/epoch - 2ms/step
# Epoch 184/200
# 302/302 - 0s - loss: 0.4752 - accuracy: 0.7958 - val_loss: 0.5354 - val_accuracy: 0.7677 - 495ms/epoch - 2ms/step
# Epoch 185/200
# 302/302 - 0s - loss: 0.4747 - accuracy: 0.7976 - val_loss: 0.5304 - val_accuracy: 0.7780 - 459ms/epoch - 2ms/step
# Epoch 186/200
# 302/302 - 0s - loss: 0.4745 - accuracy: 0.7970 - val_loss: 0.5376 - val_accuracy: 0.7687 - 473ms/epoch - 2ms/step
# Epoch 187/200
# 302/302 - 0s - loss: 0.4744 - accuracy: 0.7972 - val_loss: 0.5320 - val_accuracy: 0.7771 - 462ms/epoch - 2ms/step
# Epoch 188/200
# 302/302 - 0s - loss: 0.4752 - accuracy: 0.7967 - val_loss: 0.5353 - val_accuracy: 0.7705 - 463ms/epoch - 2ms/step
# Epoch 189/200
# 302/302 - 0s - loss: 0.4758 - accuracy: 0.7964 - val_loss: 0.5380 - val_accuracy: 0.7733 - 444ms/epoch - 1ms/step
# Epoch 190/200
# 302/302 - 0s - loss: 0.4744 - accuracy: 0.7973 - val_loss: 0.5352 - val_accuracy: 0.7743 - 489ms/epoch - 2ms/step
# Epoch 191/200
# 302/302 - 1s - loss: 0.4757 - accuracy: 0.7975 - val_loss: 0.5331 - val_accuracy: 0.7771 - 503ms/epoch - 2ms/step
# Epoch 192/200
# 302/302 - 1s - loss: 0.4755 - accuracy: 0.7953 - val_loss: 0.5370 - val_accuracy: 0.7687 - 528ms/epoch - 2ms/step
# Epoch 193/200
# 302/302 - 0s - loss: 0.4745 - accuracy: 0.7964 - val_loss: 0.5481 - val_accuracy: 0.7659 - 481ms/epoch - 2ms/step
# Epoch 194/200
# 302/302 - 0s - loss: 0.4744 - accuracy: 0.7960 - val_loss: 0.5304 - val_accuracy: 0.7743 - 491ms/epoch - 2ms/step
# Epoch 195/200
# 302/302 - 0s - loss: 0.4734 - accuracy: 0.7958 - val_loss: 0.5345 - val_accuracy: 0.7789 - 455ms/epoch - 2ms/step
# Epoch 196/200
# 302/302 - 0s - loss: 0.4747 - accuracy: 0.7985 - val_loss: 0.5311 - val_accuracy: 0.7808 - 477ms/epoch - 2ms/step
# Epoch 197/200
# 302/302 - 0s - loss: 0.4735 - accuracy: 0.8011 - val_loss: 0.5304 - val_accuracy: 0.7771 - 477ms/epoch - 2ms/step
# Epoch 198/200
# 302/302 - 0s - loss: 0.4730 - accuracy: 0.7981 - val_loss: 0.5341 - val_accuracy: 0.7687 - 460ms/epoch - 2ms/step
# Epoch 199/200
# 302/302 - 0s - loss: 0.4734 - accuracy: 0.7961 - val_loss: 0.5293 - val_accuracy: 0.7808 - 463ms/epoch - 2ms/step
# Epoch 200/200
# 302/302 - 0s - loss: 0.4734 - accuracy: 0.8007 - val_loss: 0.5332 - val_accuracy: 0.7733 - 472ms/epoch - 2ms/step
# 335/335 [==============================] - 1s 1ms/step
# NestedLogit_nonlinear - Log-likelihood -5046.323
